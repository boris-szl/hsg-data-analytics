# %% [markdown]
# # OLS and IV

# %% [markdown]
# ## Step 1: Generating data according following linear modell:

# %% [markdown]
# ![image.png](attachment:38231eb1-7d2d-4874-b70e-30e292b486eb.png)

# %% [markdown]
# <ul>
#     <li>$y_{i}\,is\,a\,dependent\,variable$</li>
#     <li>$\beta_{0}\,is\,a\,constant\,value$</li>
#     <li>$\beta_{1,2,...,n}\,is\,a\,vektor\,coefficients$</li>
#     <li>$x_{1,2,..,n}\,is\,an\,indepedent\,variables\,(...are\,vector\,entries)...also\,known\,as\,regressor$</li>
#     <li>$u_{i}\,is\,an\,uncertainty\,value\,(captured\,by\,vector)$</li>
# </ul>

# %% [markdown]
# ### 1.1 Generate Data for:<br>
# <ul>
#     <li>$\beta$</li>
#     <li>$x$</li>
#     <li>$u$</li>
# </ul>
